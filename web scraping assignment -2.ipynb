# %% [markdown]
# # Q1: Write a python program to scrape data for “Data Analyst” Job position in “Bangalore” location. You have to scrape the job-title, job-location, company_name, experience_required. You have to scrape first 10 jobs data.
# This task will be done in following steps:
# 1. First get the webpage https://www.naukri.com/
# 2. Enter “Data Analyst” in “Skill, Designations, Companies” field and enter “Bangalore” in “enter the
# location” field.
# 3. Then click the searchbutton.
# 4. Then scrape the data for the first 10 jobs results youget.
# 5. Finally create a dataframe of the scraped data.

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By
import time

# %%
#lets connect with web driver

driver = webdriver.Chrome(r"chromedriver.exe")

# %%
#opening the naukri.com website on automated chrome browser

driver.get("https://www.naukri.com/")

# %%
#Finding element for job search bar

designation=driver.find_element(By.CLASS_NAME,"suggestor-input ")
designation.send_keys('data analyst')

# %%
#Entering Location banglore in location search bar

search_location=driver.find_element(By.XPATH,'/html/body/div[1]/div[7]/div/div/div[5]/div/div/div/div[1]/div/input')
search_location.send_keys('Bangalore')

# %%
#Clicking on search bar button

search=driver.find_element(By.CLASS_NAME,'qsbSubmit')
search.click()

# %%
#creating empty lists for storing data

job_title=[]
job_location=[]
company_name=[]
experience_required=[]

# %%
#extracting different tags

title_tags=driver.find_elements(By.XPATH,'//a[@class="title ellipsis"]')
for i in title_tags[0:10]:
    title=i.text
    job_title.append(title)
    
    
location_tags=driver.find_elements(By.XPATH,'//span[@class="ellipsis fleft locWdth"]')
for i in location_tags[0:10]:
    location=i.text
    job_location.append(location)
    
    
company_tags=driver.find_elements(By.XPATH,'//a[@class="subTitle ellipsis fleft"]')
for i in company_tags[0:10]:
    company=i.text
    company_name.append(company)
    
    
    
experience_tags=driver.find_elements(By.XPATH,'//span[@class="ellipsis fleft expwdth"]')
for i in experience_tags[0:10]:
    exp=i.text
    experience_required.append(exp)

# %%
#checking the lengths

print(len(job_title),len(job_location),len(company_name),len(experience_required))
# Out:
# 10 10 10 10

# %%
#creating pandas dataframe

df=pd.DataFrame({'Job_title':job_title,'Job_Location':job_location,'Comapny_name':company_name,'Experience':experience_required})

df
# Out:
#                                            Job_title
# 0  Permanent Opportunity - Data Scientist(Snaplog...  \
# 1                   Analystics & Modeling Specialist
# 2                          Hiring For Data Scientist
# 3                                 Data Scientist_NLP
# 4                    Machine Learning (AI) Architect
# 5            Director/Senior Director - Data Science
# 6              Manager/Senior Manager - Data Science
# 7                                     Data Scientist
# 8                                     Data Scientist
# 9                                     Data Scientist
#
#                                         Job_Location
# 0  Hybrid - Bangalore/Bengaluru, Kolkata, Hyderab...  \
# 1  Bangalore/Bengaluru, Kolkata, Mumbai, Hyderaba...
# 2  Hybrid - Bangalore/ Bengaluru, Karnataka, Hyde...
# 3  Bangalore/Bengaluru, Mumbai, Pune, Chennai, Gu...
# 4  Bangalore/Bengaluru, Kolkata, Mumbai, New Delh...
# 5  Bangalore/Bengaluru, Noida, Hyderabad/Secunder...
# ...

# %% [markdown]
# # Q2:Write a python program to scrape data for “Data Scientist” Job position in “Bangalore” location. You have to scrape the job-title, job-location, company_name. You have to scrape first 10 jobs data.This task will be done in following steps:
# 1. First get the webpage https://www.naukri.com/
# 2. Enter “Data Scientist” in “Skill, Designations, Companies” field and enter “Bangalore” in “enter the
# location” field.
# 3. Then click the searchbutton.
# 4. Then scrape the data for the first 10 jobs results youget.
# 5. Finally create a dataframe of the scraped data.

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By
import time

# %%
#connect with web driver

driver = webdriver.Chrome(r"chromedriver.exe")

# %%
#opening the naukri.com website on automated chrome browser

driver.get("https://www.naukri.com/")

# %%
#Finding element for job search bar

designation=driver.find_element(By.CLASS_NAME,"suggestor-input ")
designation.send_keys('data scientist')

# %%
#Entering Location banglore in location search bar

search_location=driver.find_element(By.XPATH,'/html/body/div[1]/div[7]/div/div/div[5]/div/div/div/div[1]/div/input')
search_location.send_keys('Bangalore')

# %%
#Clicking on search bar button

search=driver.find_element(By.CLASS_NAME,'qsbSubmit')
search.click()

# %%
#creating empty lists for storing data

job_title=[]
job_location=[]
company_name=[]

# %%
#extracting different tags

title_tags=driver.find_elements(By.XPATH,'//a[@class="title ellipsis"]')
for i in title_tags[0:10]:
    title=i.text
    job_title.append(title)
    
    
location_tags=driver.find_elements(By.XPATH,'//span[@class="ellipsis fleft locWdth"]')
for i in location_tags[0:10]:
    location=i.text
    job_location.append(location)
    
    
company_tags=driver.find_elements(By.XPATH,'//a[@class="subTitle ellipsis fleft"]')
for i in company_tags[0:10]:
    company=i.text
    company_name.append(company)

# %%
#checking the lengths

print(len(job_title),len(job_location),len(company_name))
# Out:
# 10 10 10

# %%
#creating pandas dataframe

df=pd.DataFrame({'Job_title':job_title,'Job_Location':job_location,'Company_Name':company_name})

df
# Out:
#                                            Job_title
# 0  Permanent Opportunity - Data Scientist(Snaplog...  \
# 1                   Analystics & Modeling Specialist
# 2                          Hiring For Data Scientist
# 3                                 Data Scientist_NLP
# 4                    Machine Learning (AI) Architect
# 5            Director/Senior Director - Data Science
# 6              Manager/Senior Manager - Data Science
# 7                                     Data Scientist
# 8                                     Data Scientist
# 9                                     Data Scientist
#
#                                         Job_Location
# 0  Hybrid - Bangalore/Bengaluru, Kolkata, Hyderab...  \
# 1  Bangalore/Bengaluru, Kolkata, Mumbai, Hyderaba...
# 2  Hybrid - Bangalore/ Bengaluru, Karnataka, Hyde...
# 3  Bangalore/Bengaluru, Mumbai, Pune, Chennai, Gu...
# 4  Bangalore/Bengaluru, Kolkata, Mumbai, New Delh...
# 5  Bangalore/Bengaluru, Noida, Hyderabad/Secunder...
# ...

# %% [markdown]
# # Q3: In this question you have to scrape data using the filters available on the webpage as shown below:
#
# You have to use the location and salary filter.
# You have to scrape data for “Data Scientist” designation for first 10 job results.
# You have to scrape the job-title, job-location, company name, experience required.
# The location filter to be used is “Delhi/NCR”. The salary filter to be used is “3-6” lakhs
# The task will be done as shown in the below steps:
# 1. first get thewebpage https://www.naukri.com/
# 2. Enter “Data Scientist” in “Skill, Designations, and Companies” field.
# 3. Then click the searchbutton.
# 4. Then apply the location filter and salary filter by checking the respectiveboxes
# 5. Then scrape the data for the first 10 jobs results youget.
# 6. Finally create a dataframe of the scrapeddata.

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By
import time

# %%
#connect with web driver

driver = webdriver.Chrome(r"chromedriver.exe")

# %%
#opening the naukri.com website on automated chrome browser

driver.get("https://www.naukri.com/")

# %%
#Finding element for job search bar

designation=driver.find_element(By.CLASS_NAME,"suggestor-input ")
designation.send_keys('data scientist')

# %%
#Clicking on search bar button

search=driver.find_element(By.CLASS_NAME,'qsbSubmit')
search.click()

# %%
#do the tick mark on location filter bar

click_location_button =driver.find_element(By.XPATH,'/html/body/div[1]/div[4]/div/div/section[1]/div[2]/div[2]/div[2]/div[1]/label/p/span[1]')
click_location_button.click()
time.sleep(3)

# %%
#do tick mark on salary filter bar

click_salary_button =driver.find_element(By.XPATH,'/html/body/div[1]/div[4]/div/div/section[1]/div[2]/div[3]/div[2]/div[1]/label/p/span[1]')
click_salary_button.click()
time.sleep(3)

# %%
#Creating empty lists for storing data

job_title=[]
job_location=[]
company_name=[]
experience_required=[]

# %%
#extracting different tags

title_tags=driver.find_elements(By.XPATH,'//a[@class="title ellipsis"]')
for i in title_tags[0:10]:
    title=i.text
    job_title.append(title)
    
    
location_tags=driver.find_elements(By.XPATH,'//span[@class="ellipsis fleft locWdth"]')
for i in location_tags[0:10]:
    location=i.text
    job_location.append(location)
    
    
company_tags=driver.find_elements(By.XPATH,'//a[@class="subTitle ellipsis fleft"]')
for i in company_tags[0:10]:
    company=i.text
    company_name.append(company)
    
    
    
experience_tags=driver.find_elements(By.XPATH,'//span[@class="ellipsis fleft expwdth"]')
for i in experience_tags[0:10]:
    exp=i.text
    experience_required.append(exp)

# %%
#Checking the lengths

print(len(job_title),len(job_location),len(company_name),len(experience_required))
# Out:
# 10 10 10 10

# %%
#creating pandas dataframe

df=pd.DataFrame({'Job_title':job_title,'Job_Location':job_location,'Comapny_name':company_name,'Experience':experience_required})

df
# Out:
#                                  Job_title
# 0         Analystics & Modeling Specialist  \
# 1                       Data Scientist_NLP
# 2          Machine Learning (AI) Architect
# 3  Director/Senior Director - Data Science
# 4    Manager/Senior Manager - Data Science
# 5                           Data Scientist
# 6        Team Lead/Consultant-Data Science
# 7                           Data Scientist
# 8    Senior Customer Facing Data Scientist
# 9                    Senior Data Scientist
#
#                                         Job_Location
# 0  Kolkata, Mumbai, Hyderabad/Secunderabad, Pune,...  \
# 1  Mumbai, Pune, Chennai, Gurgaon/Gurugram, Banga...
# 2  Kolkata, Mumbai, New Delhi, Hyderabad/Secunder...
# 3  Noida, Hyderabad/Secunderabad, Pune, Gurgaon/G...
# 4  Noida, Hyderabad/Secunderabad, Pune, Gurgaon/G...
# 5  Hyderabad/Secunderabad, Chennai, Bangalore/Ben...
# 6                                             Mumbai
# 7                                Bangalore/Bengaluru
# ...

# %% [markdown]
# # Q4: Scrape data of first 100 sunglasses listings on flipkart.com. You have to scrape four attributes:
# 1. Brand
# 2. ProductDescription
# 3. Price
# The attributes which you have to scrape is ticked marked in the below image
#
# To scrape the data you have to go through following steps:
# 1. Go to Flipkart webpage by url :https://www.flipkart.com/
# 2. Enter “sunglasses” in the search field where “search for products, brands and more” is written and
# click the search icon
# 3. After that you will reach to the page having a lot of sunglasses. From this page you can scrap the
# required data asusual.
# 4. After scraping data from the first page, go to the “Next” Button at the bottom other page , then
# click on it.
# 5. Now scrape data from this page asusual
# 6. Repeat this until you get data for 100sunglasses

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By
import time

# %%
#connect with web driver

driver = webdriver.Chrome(r"chromedriver.exe")

# %%
#onpening the flipkart website on automated chrome browser
driver.get('https://www.flipkart.com/')
time.sleep(3)

# %%
#remove the pop up page
pop_up_page =driver.find_element(By.XPATH,'/html/body/div[2]/div/div/button')
pop_up_page.click()
time.sleep(3)

# %%
#search the “sunglasses” and click search button 

search_product = driver.find_element(By.CLASS_NAME,'_3704LK')
search_product.send_keys('sunglasses')

# %%
#click on the search buttone

search_button =driver.find_element(By.XPATH,'/html/body/div[1]/div/div[1]/div[1]/div[2]/div[2]/form/div/button')
search_button.click()
time.sleep(5)

# %%
#creating empty lists for storing data

Brand = []
Product_Description = []
Price= []
Discount_value=[]

# for searching in 3 pages
for i in range(3):
    brand = driver.find_elements(By.XPATH,"//div[@class='_2WkVRV']")
    for i in brand:Brand.append(i.text)
    
    product_des = driver.find_elements(By.XPATH,"//a[@class='IRpwTa']")
    for i in product_des:Product_Description.append(i.text)    
    
    price = driver.find_elements(By.XPATH,"//div[@class='_30jeq3']")
    for i in price:Price.append(i.text)
        
    discount = driver.find_elements(By.XPATH,'//div[@class="_3Ay6Sb"]')
    for i in discount:Discount_value.append(i.text)
    
time.sleep(3)        
        
        
nxt_button=driver.find_element(By.XPATH,"//a[@class='_1LKTO3']")#scraping the list of buttons from the page
nxt_button.click()

# %%
#checking the lengths

print(len(Brand),len(Product_Description),len(Price),len(Discount_value))
# Out:
# 120 111 120 120

# %%
#creating pandas dataframe

df=pd.DataFrame()
df["BRAND"]=Brand[:100]
df["PRODUCT_DESCRIPTION"]=Product_Description[:100]
df["PRICE"]=Price[:100]
df["Discount"]=Discount_value[:100]
df
# Out:
#            BRAND                                PRODUCT_DESCRIPTION PRICE
# 0          NuVew               UV Protection Sports Sunglasses (65)  ₹129  \
# 1   Singco India  UV Protection, Riding Glasses Rectangular Sung...  ₹396
# 2      Elligator           UV Protection Clubmaster Sunglasses (54)  ₹109
# 3       Fastrack       UV Protection Aviator Sunglasses (Free Size)  ₹499
# 4         PIRASO  Gradient, UV Protection Wayfarer Sunglasses (F...  ₹215
# ..           ...                                                ...   ...
# 95     ROYAL SON    Gradient, UV Protection Aviator Sunglasses (57)  ₹899
# 96    iCopertina      UV Protection Wayfarer Sunglasses (Free Size)  ₹199
# 97         jiebo       UV Protection Aviator Sunglasses (Free Size)  ₹209
# 98      Fastrack   Polarized, UV Protection Aviator Sunglasses (58)  ₹599
# 99        AISLIN  Mirrored, UV Protection Wayfarer Sunglasses (F...  ₹730
#
#    Discount
# 0   86% off
# 1   80% off
# 2   91% off
# 3   44% off
# ...

# %% [markdown]
# # Q5: Scrape 100 reviews data from flipkart.com for iphone11 phone. You have to go the link:
# https://www.flipkart.com/apple-iphone-11-black-64-gb/product-reviews/itm4e5041ba101fd?pid=MOBFWQ6BXGJCEYNY&lid=LSTMOBFWQ6BXGJCEYNYZXSHRJ&marketplace=FLIPKART
#
# As shown in the above page you have to scrape the tick marked attributes. These are:
# 1. Rating
# 2. Review summary
# 3. Full review
# 4. You have to scrape this data for first 100reviews

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By
import time

# %%
#connect with web driver

driver = webdriver.Chrome(r"chromedriver.exe")

# %%
#onpening the flipkart website on automated chrome browser

driver.get("https://www.flipkart.com/")

# %%
#remove the pop up page

pop_up_page =driver.find_element(By.XPATH,'/html/body/div[2]/div/div/button')
pop_up_page.click()

# %%
#search the “sunglasses” and click search button 

search_product = driver.find_element(By.CLASS_NAME,'_3704LK')
search_product.send_keys('iphone 11')

# %%
#click on the search buttone

search_button =driver.find_element(By.XPATH,'/html/body/div[1]/div/div[1]/div[1]/div[2]/div[2]/form/div/button')
search_button.click()
time.sleep(2)

# %%
#lets select the first phone

click_first_phone =driver.find_element(By.XPATH,"/html/body/div[1]/div/div[3]/div[1]/div[2]/div[2]/div/div/div/a/div[2]/div[1]/div[1]")
click_first_phone.click()

# %%
#creating empty list for storing data

Rating = []
Review_Summary = []
Full_Review = []

# %%
#for searching in 10 pages
for i in range(10):
    Review_Sum=driver.find_elements(By.XPATH,'//p[@class="_2-N8zT"]')###to get the review summary
    for i in Review_Sum:
        Review_Summary.append(i.text)
        
    Ratings=driver.find_elements(By.XPATH,'//div[@class="_3LWZlK _1BLPMq"]')###to get the rating
    for i in Ratings:
        Rating.append(i.text)
        
    Review=driver.find_elements(By.XPATH,'//div[@class="t-ZTKy"]')###to get the full review
    for i in Review:
        Full_Review.append(i.text)
        

#letting the python sleep during page loading        
time.sleep(5)

# %%
#checking the lengths

print(len(Rating),len(Review_Summary),len(Full_Review))
# Out:
# 240 240 240

# %%
#creating Pandas dataframe

df = pd.DataFrame({'Ratings':Rating,'Review':Review_Summary,'Full Review':Full_Review})

df[:100]
# Out:
#    Ratings                Review
# 0        4  Good quality product  \
# 1        5      Perfect product!
# 2        5        Simply awesome
# 3        5               Awesome
# 4        5             Fabulous!
# ..     ...                   ...
# 95       5         Great product
# 96       4  Good quality product
# 97       5      Perfect product!
# 98       5        Simply awesome
# 99       5               Awesome
#
#                                           Full Review
# 0   impressively Nice......\nOne of the greatest i...
# 1                          Nice products thanks flkat
# 2   Really satisfied with the Product I received.....
# 3                          excellent forever and ever
# 4   Fast performance to previous iPhone x\nGood ca...
# ..                                                ...
# 95           Awesome product ❤️❤️\nThank you Flipkart
# 96  impressively Nice......\nOne of the greatest i...
# 97                         Nice products thanks flkat
# ...

# %% [markdown]
# # Q.6: Scrape data forfirst 100 sneakers you find when you visit flipkart.com and search for “sneakers” in the
# search field.
# You have to scrape 3 attributes of each sneaker:
# 1. Brand
# 2. ProductDescription
# 3. Price

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By
import time

# %%
#connect with web driver

driver = webdriver.Chrome(r"chromedriver.exe")

# %%
#onpening the flipkart website on automated chrome browser

driver.get('https://www.flipkart.com/')
time.sleep(2)

# %%
#for closing the pop up window

pop_close = driver.find_element(By.XPATH,"/html/body/div[2]/div/div/button")
pop_close.click()

# %%
#entering sneakers in the search bar

search_item = driver.find_element(By.CLASS_NAME,"_3704LK")
search_item.send_keys("sneakers")
time.sleep(3)

# %%
#clicking the search button

click_search_button = driver.find_element(By.XPATH,"/html/body/div[1]/div/div[1]/div[1]/div[2]/div[2]/form/div/button")
click_search_button.click()
time.sleep(3)

# %%
#creating empty lists for storing data 

Brand = []
Product_Description = []
Price = []

# %%
for i in range(3):
    
    brand = driver.find_elements(By.XPATH,"//div[@class='_2WkVRV']")
    for i in brand:
        Brand.append(i.text)
        
    product_des = driver.find_elements(By.XPATH,"//a[@class='IRpwTa']")
    for i in product_des:
        Product_Description.append(i.text)
        
    price = driver.find_elements(By.XPATH,"//div[@class='_30jeq3']")    
    for i in price :
        Price.append(i.text)
    
time.sleep(3)

nxt_button = driver.find_element(By.XPATH,"//a[@class='_1LKTO3']")
nxt_button.click()

# %%
#checking the lengths

print(len(Brand),len(Product_Description),len(Price))
# Out:
# 120 120 120

# %%
#Creating pandas dataframe

df = pd.DataFrame({'Brand':Brand,'Product_Description':Product_Description,'Price':Price})

df[0:100]
# Out:
#                   Brand                                Product_Description
# 0           kardam&sons  Fashionable Canvas Casual Partywear Outdoor Sn...  \
# 1                  aadi  Mesh| Lightweight| Premiun| Comfort| Summer Te...
# 2                  aadi  Synthetic Leather |Lightweight|Comfort|Summer|...
# 3                  aadi  Synthetic| Lightweight| Premiun| Comfort| Summ...
# 4   World Wear Footwear  Latest Exclusive Affordable Collection of Tren...
# ..                  ...                                                ...
# 95  World Wear Footwear  Latest Exclusive Affordable Collection of Tren...
# 96          kardam&sons  Fashionable Canvas Casual Partywear Outdoor Sn...
# 97                 aadi  Mesh |Lightweight|Comfort|Summer|Trendy|Walkin...
# 98                BIRDE      Premium Casual Shoes for Men Sneakers For Men
# 99                 PUMA                            Player Sneakers For Men
#
#      Price
# 0     ₹449
# 1     ₹349
# 2     ₹249
# 3     ₹249
# ...

# %% [markdown]
# # Q.7: Go to webpage https://www.amazon.in/ Enter “Laptop” in the search field and then click the search icon. Then set CPU Type filter to “Intel Core i7” as shown in the below image:
#
# After setting the filters scrape first 10 laptops data. You have to scrape 3 attributes for each laptop:
# 1. Title
# 2. Ratings
# 3. Price

# %%
import selenium
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
from selenium import webdriver
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.by import By
import time

# %%
#connect with web driver

driver = webdriver.Chrome(r"chromedriver.exe")

# %%
#opening the amazon website on automated chrome browser

driver.get('https://www.amazon.in/')
time.sleep(2)

# %%
#entering Laptop in search bar

search_item = driver.find_element(By.XPATH,"//input[@class='nav-input nav-progressive-attribute']")
search_item.send_keys("laptop")

# %%
#Clicking the search button

click_search_button = driver.find_element(By.XPATH,"//input[@id='nav-search-submit-button']")
click_search_button.click()
time.sleep(3)

# %%
#to select the core i7 filter

i7=driver.find_element(By.XPATH,'//*[@id="p_n_feature_thirteen_browse-bin/12598163031"]/span/a/span')
i7.click()

# %%
#creating empty lists for storing data

Title = []
Ratings = []
Price = []

# %%
title = driver.find_elements(By.XPATH,"//span[@class='a-size-medium a-color-base a-text-normal']")
for i in title:
    Title.append(i.text)
    
rating = driver.find_elements(By.XPATH,"//div[@class='a-row a-size-small']")
for i in rating:
    Ratings.append(i.text)  
    
price = driver.find_elements(By.XPATH,"//span[@class='a-price-whole']")
for i in price:
    Price.append(i.text)

# %%
#Checking the lengths

print(len(Title),len(Ratings),len(Price))
# Out:
# 24 27 32

# %%
#Creating Pandas Dataframe and making lengths same

df=pd.DataFrame()
df["Title"]=Title[:10]
df["Ratings"]=Ratings[:10]
df["PRICE"]=Price[:10]
df
# Out:
#                                                Title Ratings     PRICE
# 0  ASUS TUF Gaming F15 (2023) 90WHr Battery, Inte...       3  1,15,990
# 1  Acer Predator Helios Neo 16 Gaming Laptop 13th...       1  1,49,990
# 2  Acer Predator Helios Neo 16 Gaming Laptop 13th...       6  1,29,990
# 3  Lenovo ThinkPad E14 Intel Core i7 12th Gen 14"...      18    98,990
# 4  ASUS TUF Gaming F15 (2022), 15.6"(39.62 cms) F...      80    93,990
# 5  HP Pavilion Plus, 12th Gen Intel Core i7 16GB ...     163    93,990
# 6  HP Victus Gaming Latest 12th Gen Intel Core i7...     325    90,990
# 7  Lenovo IdeaPad Slim 5 Intel Core i7 12th Gen 1...      67    79,990
# 8  (Renewed) Dell Latitude E7470 Intel Core i7 6t...      81    29,768
# 9  HP Pavilion 14, 11Th Gen Intel Core I7-16Gb Ra...      24    83,680

# %% [markdown]
# # Q.8: Write a python program to scrape data for Top 1000 Quotes of All Time.
# The above task will be done in following steps:
# 1. First get the webpagehttps://www.azquotes.com/
# 2. Click on TopQuotes
# 3. Than scrap
# a) Quote b) Author c) Type Of Quotes

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By
import time

# %%
#connect with web driver

driver = webdriver.Chrome(r"chromedriver.exe")

# %%
#opening the azquotes website on automated chrome browser

driver.get('https://www.azquotes.com/')
time.sleep(2)

# %%
#Clicking top quotes

click_TopQuotes = driver.find_element(By.XPATH,"/html/body/div[1]/div[1]/div[1]/div/div[3]/ul/li[5]/a")
click_TopQuotes.click()
time.sleep(3)

# %%
#Creating empty lists for storing data

Quote_name=[]
Author_name=[]
Types_of_quotes=[]

# %%
for i in range(3):
    quote = driver.find_elements(By.XPATH,"//a[@class='title']")
    for i in quote:
        Quote_name.append(i.text)
    
    author = driver.find_elements(By.XPATH,"//div[@class='author']")
    for i in author:    
        Author_name.append(i.text)  
    
    typeofname = driver.find_elements(By.XPATH,"//div[@class='tags']")
    for i in typeofname:
        Types_of_quotes.append(i.text)

# %%
#Checking the length

print(len(Quote_name),len(Author_name),len(Types_of_quotes))
# Out:
# 1200 1200 1200

# %%
#Creating Pandas Dataframe

df = pd.DataFrame({'Quote':Quote_name,'Author':Author_name,'Types of Quote':Types_of_quotes})
df[:1000]
# Out:
#                                                  Quote                Author
# 0    The essence of strategy is choosing what not t...        Michael Porter  \
# 1    One cannot and must not try to erase the past ...            Golda Meir
# 2    Patriotism means to stand by the country. It d...    Theodore Roosevelt
# 3    Death is something inevitable. When a man has ...        Nelson Mandela
# 4    You have to love a nation that celebrates its ...          Erma Bombeck
# ..                                                 ...                   ...
# 995     When the going gets weird, the weird turn pro.    Hunter S. Thompson
# 996  When a train goes through a tunnel and it gets...       Corrie Ten Boom
# 997  If you think you are too small to make a diffe...            Dalai Lama
# 998  God doesn't require us to succeed, he only req...         Mother Teresa
# 999    Change your thoughts and you change your world.  Norman Vincent Peale
#
# ...

# %% [markdown]
# # Q.9: Write a python program to display list of respected former Prime Ministers of India(i.e. Name, Born-Dead, Term of office, Remarks) from https://www.jagranjosh.com/.
# This task will be done in following steps:
# 1. First get the webpagehttps://www.jagranjosh.com/
# 2. Then You have to click on the GK option
# 3. Then click on the List of all Prime Ministers of India
# 4. Then scrap the mentioned data and make theDataFrame.

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By
from selenium.common.exceptions import StaleElementReferenceException,NoSuchElementException
import time

# %%
#connect with web driver

driver = webdriver.Chrome(r"chromedriver.exe")

# %%
#opening the jagranjosh website on automated chrome browser

driver.get('https://www.jagranjosh.com')
time.sleep(3)

# %%
#to click GK option

GK=driver.find_element(By.XPATH,'//*[@id="1540978020504"]/div[1]/header/div[3]/ul/li[9]/a')
GK.click()
time.sleep(3)

# %%
#Cookie_close = driver.find_element(By.XPATH,"/html/body/div/div/div/div[3]/div/div[2]/div/div[3]/div/a[3]")
#Cookie_close.click()

# %%
#to click list of Prime Ministers of India

PMS=driver.find_element(By.XPATH,'//*[@id="1665572069040"]/div[1]/header/div[3]/ul/li[3]/a')
PMS.click()
time.sleep(3)

# %%
#list of prime-ministers

pm_list = driver.find_element(By.XPATH,'//*[@id="popluarGK"]/ul/li[2]/a')
pm_list.click()
time.sleep(2)

# %%
#Creating empty list for storing data

Detail=[]
Name=[]
Born_Dead=[]
Term_Of_Office=[]
Remarks=[]

# %%
#as the data tags are not similar for all the different names, we can extract all the data with data tagname in single list
#then we can split the data as required

Details=driver.find_elements(By.TAG_NAME,'tr')
for i in Details:
    Detail.append(i.text)

Detail
# Out:
# ['S.N.\nName\nBorn-Dead\nTerm of office\nRemark',
#  '1.\nJawahar Lal Nehru\n(1889–1964)\n15 August 1947 to 27 May 1964\n16 years, 286 days\nThe first prime minister of India and the longest-serving PM of India, the first to die in office.',
#  '2.\nGulzarilal Nanda (Acting)\n(1898-1998)\n27 May 1964 to 9 June 1964,\n13 days\nFirst acting PM of India',
#  "3.\nLal Bahadur Shastri\n(1904–1966)\n9 June 1964 to 11 January 1966\n1 year, 216 days\nHe has given the slogan of 'Jai Jawan Jai Kisan' during the Indo-Pak war of 1965",
#  '4. \nGulzari Lal Nanda  (Acting)\n(1898-1998)\n11 January 1966 to 24 January 1966\n13 days\n-',
#  '5.\nIndira Gandhi\n(1917–1984)\n24 January 1966 to 24 March 1977\n11 years, 59 days\nFirst female Prime Minister of India',
#  '6.\nMorarji Desai\n(1896–1995)\n24 March 1977 to  28 July 1979 \n2 year, 126 days\nOldest to become PM (81 years old) and first to resign from office',
# ...

# %%
#creating new empty list for storing the data and splitting the each item at \n

table=[]
for i in range(1,19):
    data=Detail[i].split('\n')
    table.append(data)
    
table
# Out:
# [['1.',
#   'Jawahar Lal Nehru',
#   '(1889–1964)',
#   '15 August 1947 to 27 May 1964',
#   '16 years, 286 days',
#   'The first prime minister of India and the longest-serving PM of India, the first to die in office.'],
#  ['2.',
#   'Gulzarilal Nanda (Acting)',
#   '(1898-1998)',
#   '27 May 1964 to 9 June 1964,',
#   '13 days',
#   'First acting PM of India'],
#  ['3.',
#   'Lal Bahadur Shastri',
#   '(1904–1966)',
#   '9 June 1964 to 11 January 1966',
#   '1 year, 216 days',
#   "He has given the slogan of 'Jai Jawan Jai Kisan' during the Indo-Pak war of 1965"],
#  ['4. ',
#   'Gulzari Lal Nanda  (Acting)',
#   '(1898-1998)',
#   '11 January 1966 to 24 January 1966',
#   '13 days',
#   '-'],
#  ['5.',
#   'Indira Gandhi',
#   '(1917–1984)',
#   '24 January 1966 to 24 March 1977',
#   '11 years, 59 days',
#   'First female Prime Minister of India'],
#  ['6.',
#   'Morarji Desai',
#   '(1896–1995)',
#   '24 March 1977 to  28 July 1979 ',
#   '2 year, 126 days',
# ...

# %%
#checking length of table

len(table)
# Out:
# 18

# %%
#Creating Pandas Dataframe

List_of_PMs = pd.DataFrame(table, columns = ['S.No','NAME','Born-Dead','Term','Term in years & Days','Remarks']).set_index('S.No')
List_of_PMs
# Out:
#                              NAME     Born-Dead
# S.No
# 1.              Jawahar Lal Nehru   (1889–1964)  \
# 2.      Gulzarilal Nanda (Acting)   (1898-1998)
# 3.            Lal Bahadur Shastri   (1904–1966)
# 4.    Gulzari Lal Nanda  (Acting)   (1898-1998)
# 5.                  Indira Gandhi   (1917–1984)
# 6.                  Morarji Desai   (1896–1995)
# 7.                   Charan Singh   (1902–1987)
# 8.                  Indira Gandhi   (1917–1984)
# 9.                   Rajiv Gandhi   (1944–1991)
# 10.                   V. P. Singh   (1931–2008)
# 11.               Chandra Shekhar   (1927–2007)
# 12.           P. V. Narasimha Rao   (1921–2004)
# 13.          Atal Bihari Vajpayee  (1924- 2018)
# 14.              H. D. Deve Gowda   (born 1933)
# 15.            Inder Kumar Gujral   (1919–2012)
# 16.          Atal Bihari Vajpayee   (1924-2018)
# 17.                Manmohan Singh   (born 1932)
# 18.                 Narendra Modi   (born 1950)
#
# ...

# %% [markdown]
# # Q.10: Write a python program to display list of 50 Most expensive cars in the world (i.e. Car name and Price) from https://www.motor1.com/
# This task will be done in following steps:
# 1. First get the webpagehttps://www.motor1.com/
# 2. Then You have to type in the search bar ’50 most expensive cars’
# 3. Then click on 50 most expensive carsin the world..
# 4. Then scrap the mentioned data and make the dataframe.

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By
import time

# %%
#connect with web driver

driver = webdriver.Chrome(r"chromedriver.exe")

# %%
#opening the motor1 website on automated chrome browser

driver.get('https://www.motor1.com/')
time.sleep(2)

# %%
#to click the features button

menu=driver.find_element(By.XPATH,'//*[@id="page_index_index_index"]/div[2]/div/div/div[1]/div')
menu.click()

# %%
dropdown=driver.find_element(By.XPATH,'/html/body/div[4]/div[1]/div[3]/ul/li[5]/button')
dropdown.click()

# %%
#to click the lists option

lists=driver.find_element(By.XPATH,'/html/body/div[4]/div[1]/div[3]/ul/li[6]/ul/li[1]/a')
lists.click()
time.sleep(3)

# %%
#to click on the required link 50 most expensive cars

link=driver.find_element(By.XPATH,'//*[@id="page_index_articles_browse"]/div[8]/div[1]/div[1]/div/div/div[8]/div/div[1]/h3/a')
link.click()
time.sleep(3)

# %%
#creating empty list for storing the data

Car_Name=[]
Descriptions=[]
Price=[]

# %%
#name extraction, contains extra sub heading, that can be removed with index later

Name=driver.find_elements(By.CLASS_NAME,'subheader')
for i in Name:
    Car_Name.append(i.text)
    
    

##in description we are getting all the data of prices as well as description, with p tag
Descr=driver.find_elements(By.TAG_NAME,'p')
for i in Descr:
    Descriptions.append(i.text)
    
    
Descriptions
# Out:
# ['When it comes to high-end hypercars and super-fast supercars, a few companies should come to mind first: Bugatti, Ferrari, Koenigsegg, Rimac, and Pagani, among others. These manufacturers have cemented themselves as the top dogs in the supercar and hypercar space, extending to their wealthiest clientele the fastest, rarest, prettiest – and in this case – most expensive cars on the planet.',
#  "But in order to find out which of these unattainable-to-most vehicles is the priciest, we've scoured the invoice sheets and uncovered 50 cars all worth $1 million or more. The group includes hybrid Ferrari convertibles, an American speed king, a few electric Hypercars, and two a one-of-a-kind Rolls-Royce cars built for royalty.",
# ...

# %%
len(Descriptions)
# Out:
# 113

# %%
#as the description and prices came in same tag, extracting the price seperated

Prices=[]
for i in range(3,len(Descriptions)-6,2):
    cost=(Descriptions[i])
    Prices.append(cost)
    
len(Prices)
# Out:
# 52

# %%
#as the description and prices came in same tag, extracting the Description seperated

Description=[]
for i in range(4,len(Descriptions)-6,2):
    Desc=(Descriptions[i])
    Description.append(Desc)
    
len(Description)
# Out:
# 52

# %%
#Creating a pandas data Frame

50_Most_Expensive_Cars=pd.DataFrame({"Car_Name":Car_Name[0:50],"Prices":Prices[:50],"Description":Description[:50]})
50_Most_Expensive_Cars
# Out:
#                            Car_Name
# 0                     De Tomaso P72  \
# 1                 Ferrari LaFerrari
# 2                     Pagani Huayra
# 3                      McLaren Elva
# 4                       Czinger 21C
# 5                     Ferrari Monza
# 6                Gordon Murray T.33
# 7                 Koenigsegg Gemera
# 8                       Zenvo TSR-S
# 9                Hennessey Venom F5
# 10                  Bentley Bacalar
# 11    Hispano Suiza Carmen Boulogne
# 12           Bentley Mulliner Batur
# 13                     Deus Vayanne
# 14                      SSC Tuatara
# 15                      Lotus Evija
# 16              Aston Martin Vulcan
# 17                       Delage D12
# 18                McLaren Speedtail
# 19                     Rimac Nevera
# 20                    Pagani Utopia
# 21             Pininfarina Battista
# 22                Ferrari FXX K Evo
# 23               Gordon Murray T.50
# 24             Lamborghini Countach
# ...
